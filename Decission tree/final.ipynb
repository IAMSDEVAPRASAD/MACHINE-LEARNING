# %%
import tensorflow_decision_forests as tfdf
import pandas

# %%
path = "/home/dell/Jupyter notebook datas/csv files/archive/Chernobyl_ Chemical_Radiation.csv"
train_df = pandas.read_csv(path, nrows=77,usecols=[2,6,7,8])

# %%
train_df
# Out:
#        Location  I_131_(Bq/m3)  Cs_134_(Bq/m3)  Cs_137_(Bq/m3)
# 0         RISOE        1.00000         0.00000         0.24000
# 1         RISOE        0.00460         0.00054         0.00098
# 2         RISOE        0.01470         0.00430         0.00740
# 3         RISOE        0.00061         0.00000         0.00009
# 4         RISOE        0.00075         0.00010         0.00028
# ..          ...            ...             ...             ...
# 72      ANSBACH        0.36700         0.00000         0.26300
# 73      ANSBACH        0.62200         0.00000         0.62500
# 74      ANSBACH        0.14800         0.00000         0.11000
# 75      ANSBACH        0.03800         0.00000         0.02200
# 76  BERLIN-WEST        0.08800         0.00000         0.00120
#
# [77 rows x 4 columns]

# %%
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(train_df, label="Location")

# %%
model = tfdf.keras.RandomForestModel()
model.fit(train_ds)
# Out:
# Use /tmp/tmpw_fk7thh as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:00.142839. Found 77 examples.
# Training model...
# Model trained in 0:00:00.026262
# Compiling model...
# Model compiled.
# [INFO 2023-03-18T20:23:30.618000847+05:30 kernel.cc:1214] Loading model from path /tmp/tmpw_fk7thh/model/ with prefix 5608d375263141c0
# [INFO 2023-03-18T20:23:30.6231435+05:30 decision_forest.cc:661] Model loaded with 300 root(s), 2864 node(s), and 3 input feature(s).
# [INFO 2023-03-18T20:23:30.623164896+05:30 abstract_model.cc:1311] Engine "RandomForestGeneric" built
# [INFO 2023-03-18T20:23:30.623173498+05:30 kernel.cc:1046] Use fast generic engine

# %%
tfdf.model_plotter.plot_model_in_colab(model, tree_idx=0)
# Out:
# <script src="https://d3js.org/d3.v6.min.js"></script>
# <div id="tree_plot_04ae1720ffea4ccca26a334e297b0cf7"></div>
# <script>
# /*
#  * Copyright 2021 Google LLC.
#  * Licensed under the Apache License, Version 2.0 (the "License");
#  * you may not use this file except in compliance with the License.
#  * You may obtain a copy of the License at
#  *
#  *     https://www.apache.org/licenses/LICENSE-2.0
#  *
#  * Unless required by applicable law or agreed to in writing, software
#  * distributed under the License is distributed on an "AS IS" BASIS,
#  * WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#  * See the License for the specific language governing permissions and
#  * limitations under the License.
#  */
#
# /**
#  *  Plotting of decision trees generated by TF-DF.
#  *
#  *  A tree is a recursive structure of node objects.
#  *  A node contains one or more of the following components:
#  *
# ...

# %%
test_path ="/home/dell/Jupyter notebook datas/csv files/archive/Chernobyl_ Chemical_Radiation _test.csv"
# Load the testing dataset
test_df = pandas.read_csv(test_path,usecols=[2,6,7,8])

# %%
test_df
# Out:
#         Location  I_131_(Bq/m3)  Cs_134_(Bq/m3)  Cs_137_(Bq/m3)
# 0          RISOE        1.00000          0.0000         0.24000
# 1          RISOE        0.00200          0.0009         0.00098
# 2          RISOE        0.01470          0.0020         0.00740
# 3          RISOE        0.00061          0.0000         0.00009
# 4   AACHEN(RWTH)        0.00000          0.0070         1.18400
# 5   AACHEN(RWTH)        0.00000          0.0000         1.50000
# 6   AACHEN(RWTH)        0.00000          0.0000         1.22100
# 7   AACHEN(RWTH)        0.00000          0.0010         1.31000
# 8        ANSBACH        0.62200          0.0000         0.62500
# 9        ANSBACH        0.00000          0.0000         0.10000
# 10       ANSBACH        0.03800          0.0000         0.02200
# 11   BERLIN-WEST        0.08800          0.0000         0.10000

# %%
# Convert it to a TensorFlow dataset
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(test_df, label="Location")

# Evaluate the model
model.compile(metrics=["accuracy"])

# %%
print(model.evaluate(train_ds))
print(model.evaluate(test_ds))
# Out:
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0000e+00 - accuracy: 0.9351
# [0.0, 0.9350649118423462]
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 0.0833
# [0.0, 0.0833333358168602]

# %%
model.summary()
# Out:
# Model: "random_forest_model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (3):
# 	Cs_134_(Bq/m3)
# 	Cs_137_(Bq/m3)
# 	I_131_(Bq/m3)
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "Cs_137_(Bq/m3)"  0.731707 ################
#     2.  "I_131_(Bq/m3)"  0.537075 ########
#     3. "Cs_134_(Bq/m3)"  0.333962
#
# Variable Importance: NUM_AS_ROOT:
#     1. "Cs_137_(Bq/m3)" 190.000000 ################
#     2.  "I_131_(Bq/m3)" 110.000000
#
# Variable Importance: NUM_NODES:
#     1. "Cs_137_(Bq/m3)" 459.000000 ################
#     2.  "I_131_(Bq/m3)" 426.000000 #######
#     3. "Cs_134_(Bq/m3)" 397.000000
#
# Variable Importance: SUM_SCORE:
# ...
